# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioMarentes128/Ecuaciones-lineales-p1-al-p11-Mario-1110/blob/main/Ecuaciones_del_p1_al_p11_Mario_11110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Mario Yañez 1110 NL = 53 Fecha  15/Abril/2026
# #### Ecuacion 1
#  $x + 8 = 15$
#  1. Paso 1: Procedimiento matemáticoPlanteamiento: $x + 8 = 15$
#  2. Despeje: El 8 está sumando, pasa al otro lado restando.$x = 15 - 8$
#  3. Resultado: $x = 7$

# %%
# Despejamos x restando 8 al total
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
x = 15 - 8
print(f"El valor de x es: {x}")
# Out:
# Ingrese el primer valor: 15
# Ingrese el segundo valor: 8
# El valor de x es: 7

# %% [markdown]
# #### Ecuacion 3
# $3x + 4x = 21$
# * Paso 1: Procedimiento matemático
# 1. Agrupar términos semejantes: Sumamos las $x$.$(3 + 4)x = 21 \rightarrow 7x =21$
# 2. Despeje: El 7 multiplica a la $x$, pasa dividiendo.$x = \frac{21}{7}$
# 3. Resultado: $x = 3$

# %%
# Sumamos los coeficientes (3 + 4) y dividimos el resultado
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
int(input("Ingrese el tercer valor: "))
x = 21 / (3 + 4)
print(f"El valor de x es: {int(x)}")
# Out:
# Ingrese el primer valor: 3
# Ingrese el segundo valor: 4
# Ingrese el tercer valor: 21
# El valor de x es: 3

# %% [markdown]
# #### Ecuacion 5
#  $6a - 2a + a = 20$
#  * Paso 1: Procedimiento matemático
#  1. Agrupar términos semejantes: (Recuerda que $+ a$ es lo mismo que $+ 1a$).$6a - 2a + 1a = 20 \rightarrow 5a = 20$
#  2. Despeje: El 5 pasa dividiendo.$a = \frac{20}{5}$
#  3. Resultado: $a = 4$

# %%
# Operamos los coeficientes de 'a' y dividimos
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
int(input("Ingrese el tercer valor: "))
int(input("Ingrese el cuarto valor: "))
a = 20 / (6 - 2 + 1)
print(f"El valor de a es: {int(a)}")
# Out:
# Ingrese el primer valor: 6
# Ingrese el segundo valor: 2
# Ingrese el tercer valor: 1
# Ingrese el cuarto valor: 20
# El valor de a es: 4

# %% [markdown]
# #### Ecuacion 7
# $4x + 3 = 2x + 11$
# * Paso 1: Procedimiento matemático
# 1. Agrupar términos semejantes: Pasamos las $x$ a la izquierda y los números a la derecha.$4x - 2x = 11 - 3$
# 2. Operar:$2x = 8$
# 3. Despeje:$x = \frac{8}{2}$
# 4. Resultado: $x = 4$

# %%
# Restamos coeficientes de un lado y constantes del otro
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
int(input("Ingrese el tercer valor: "))
int(input("Ingrese el cuarto valor: "))
x = (11 - 3) / (4 - 2)
print(f"El valor de x es: {int(x)}")
# Out:
# Ingrese el primer valor: 11
# Ingrese el segundo valor: 3
# Ingrese el tercer valor: 4
# Ingrese el cuarto valor: 2
# El valor de x es: 4

# %% [markdown]
# #### Ecuacion 9
# $9m + 4 = 5m + 20$
# * Paso 1: Procedimiento matemático
# 1. Agrupar términos semejantes:$9m - 5m = 20 - 4$
# 2. Operar:$4m = 16$
# 3. Despeje:$m = \frac{16}{4}$
# 4. Resultado: $m = 4$

# %%
# m = (constante derecha - constante izquierda) / (coeficiente izq - coeficiente der)
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
int(input("Ingrese el tercer valor: "))
int(input("Ingrese el cuarto valor: "))
m = (20 - 4) / (9 - 5)
print(f"El valor de m es: {int(m)}")
# Out:
# Ingrese el primer valor: 20
# Ingrese el segundo valor: 4
# Ingrese el tercer valor: 9
# Ingrese el cuarto valor: 5
# El valor de m es: 4

# %% [markdown]
# #### Ecuacion 11
# $6a + 5 = 2a + 21$
# * Paso 1: Procedimiento matemático
# 1. Agrupar términos semejantes:$6a - 2a = 21 - 5$
# 2. Operar:$4a = 16$
# 3. Despeje:$a = \frac{16}{4}$
# 4. Resultado: $a = 4$

# %%
# Resolvemos agrupando términos en una sola línea
int(input("Ingrese el primer valor: "))
int(input("Ingrese el segundo valor: "))
int(input("Ingrese el tercer valor: "))
int(input("Ingrese el cuarto valor: "))
a = (21 - 5) / (6 - 2)
print(f"El valor de a es: {int(a)}")
# Out:
# Ingrese el primer valor: 21
# Ingrese el segundo valor: 5
# Ingrese el tercer valor: 6
# Ingrese el cuarto valor: 2
# El valor de a es: 4
